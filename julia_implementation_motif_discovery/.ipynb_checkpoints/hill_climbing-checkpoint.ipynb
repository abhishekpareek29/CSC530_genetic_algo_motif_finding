# %%
include("common.jl")
maximum_restarts = 10
# Out:
# Common file resource included
# 10

# %%
function calculate_minimum_hamming_distance(motif, string)
    string_motifs = get_nth_substrings(input_motif_length, string)
    error = input_motif_length
    for substring in string_motifs
        substring_error = calculate_hamming_distance(substring, motif)
        if substring_error < error
            error = substring_error
        end
    end
    return error
end
# Out:
# calculate_minimum_hamming_distance (generic function with 1 method)

# %%
function calculate_fitness_score(motif)
    fitness_score = 0
    valid = true
    for string in input_strings
        string_score = calculate_minimum_hamming_distance(motif, string)
        if string_score > input_hamming_distance
            valid = false
        end
        fitness_score += string_score
    end
    return (fitness_score, valid)
end
# Out:
# calculate_fitness_score (generic function with 1 method)

# %%
function check_motif_fitness_score_and_validation(motif)
    motif_is_valid_for_all_strings_inputs = true
    (this_motif_fitness_score, is_motif_valid) = calculate_fitness_score(motif)
    next_motif = motif
    for i in 1:maximum_restarts
        print("motif: ",motif,"\n")
        adjecent_motif = generate_adjecent_motif(motif)
        print("adjecent_motif: ",adjecent_motif,"\n")
        (adjecent_motif_fitness_score, adjecent_valid) = calculate_fitness_score(adjecent_motif)
        print("Adjecent motif fitness score: ", adjecent_motif_fitness_score, "\n")
        if (adjecent_motif_fitness_score < this_motif_fitness_score)
            print(adjecent_motif, " is better than ", next_motif, " with ", string(this_motif_fitness_score - adjecent_motif_fitness_score), " scores.\n")
            next_motif = adjecent_motif
            break
        end
    end
    if (next_motif == motif)
        return (motif, this_motif_fitness_score, is_motif_valid)
    else
        print("Going to adjecent motif.\n\n")
        return check_motif_fitness_score_and_validation(next_motif)
    end
end
# Out:
# check_motif_fitness_score_and_validation (generic function with 1 method)

# %%
function start_hill_climbing()
    answers = []
    for i in 1:maximum_restarts
        (motif, fitness, is_valid) = check_motif_fitness_score_and_validation(generate_random_potential_motif())
        if is_valid == true
            if isequal(motif in answers, false)
                print("\n")
                push!(answers,motif)
                print(motif, " is a discovered motif with score of ", map_fitness_to_number(fitness), "\n")
            end
        else
            print(motif, " is not a motif because of ", map_fitness_to_number(fitness), " fitness score.\n")
        end
    end
    
    if length(answers) > 0
        print(string(length(answers)), " motif(s) with length of ", string(input_motif_length), " motifs were discovered.\n")
    else
        print("No motifs with length of ", string(input_motif_length), " were found.\n")
    end
end
# Out:
# start_hill_climbing (generic function with 1 method)

# %%
function map_fitness_to_number(fitness)
    return string(trunc(Int, ((input_motif_length * length(input_strings)) - (fitness / (length(input_strings) + 1)))))
end
# Out:
# map_fitness_to_number (generic function with 1 method)

# %%
# st = start_time()
start_hill_climbing()
# end_time(st)
# Out:
# motif: GATCA
# adjecent_motif: GATCA
# Adjecent motif fitness score: 2motif: GATCA
# adjecent_motif: GATCA
# Adjecent motif fitness score: 2motif: GATCA
# adjecent_motif: GCTCA
# Adjecent motif fitness score: 4motif: GATCA
# adjecent_motif: GATCA
# Adjecent motif fitness score: 2motif: GATCA
# adjecent_motif: GATGA
# Adjecent motif fitness score: 2motif: GATCA
# adjecent_motif: GCTCA
# Adjecent motif fitness score: 4motif: GATCA
# adjecent_motif: GATCT
# Adjecent motif fitness score: 2motif: GATCA
# adjecent_motif: GATCC
# Adjecent motif fitness score: 5motif: GATCA
# adjecent_motif: GATCC
# Adjecent motif fitness score: 5motif: GATCA
# adjecent_motif: GATCA
# Adjecent motif fitness score: 2
# GATCA is a discovered motif with score of 29
# motif: GAAGC
# adjecent_motif: GAACC
# Adjecent motif fitness score: 3motif: GAAGC
# adjecent_motif: GAAGC
# Adjecent motif fitness score: 1motif: GAAGC
# adjecent_motif: GAAGA
# Adjecent motif fitness score: 3motif: GAAGC
# adjecent_motif: GAAGC
# Adjecent motif fitness score: 1motif: GAAGC
# adjecent_motif: GAAGC
# Adjecent motif fitness score: 1motif: GAAGC
# adjecent_motif: GTAGC
# Adjecent motif fitness score: 4motif: GAAGC
# adjecent_motif: GAAGC
# Adjecent motif fitness score: 1motif: GAAGC
# adjecent_motif: GCAGC
# Adjecent motif fitness score: 2motif: GAAGC
# adjecent_motif: GAAGC
# Adjecent motif fitness score: 1motif: GAAGC
# adjecent_motif: GAAAC
# Adjecent motif fitness score: 2
# GAAGC is a discovered motif with score of 29
# motif: GCTGC
# adjecent_motif: GCTGA
# Adjecent motif fitness score: 3GCTGA is better than GCTGC with 1 scores.
# Going to adjecent motif.
#
# motif: GCTGA
# adjecent_motif: GCTGC
# Adjecent motif fitness score: 4motif: GCTGA
# adjecent_motif: GCTGA
# Adjecent motif fitness score: 3motif: GCTGA
# adjecent_motif: GCTTA
# Adjecent motif fitness score: 4motif: GCTGA
# adjecent_motif: GCCGA
# Adjecent motif fitness score: 6motif: GCTGA
# adjecent_motif: CCTGA
# Adjecent motif fitness score: 1CCTGA is better than GCTGA with 2 scores.
# Going to adjecent motif.
#
# motif: CCTGA
# adjecent_motif: CCTGA
# Adjecent motif fitness score: 1motif: CCTGA
# adjecent_motif: CCTGC
# Adjecent motif fitness score: 3motif: CCTGA
# adjecent_motif: CCTAA
# Adjecent motif fitness score: 1motif: CCTGA
# adjecent_motif: GCTGA
# Adjecent motif fitness score: 3motif: CCTGA
# adjecent_motif: GCTGA
# Adjecent motif fitness score: 3motif: CCTGA
# adjecent_motif: CCAGA
# Adjecent motif fitness score: 0CCAGA is better than CCTGA with 1 scores.
# Going to adjecent motif.
#
# motif: CCAGA
# adjecent_motif: CCCGA
# Adjecent motif fitness score: 3motif: CCAGA
# adjecent_motif: CCACA
# Adjecent motif fitness score: 1motif: CCAGA
# adjecent_motif: GCAGA
# Adjecent motif fitness score: 3motif: CCAGA
# adjecent_motif: GCAGA
# Adjecent motif fitness score: 3motif: CCAGA
# adjecent_motif: CCCGA
# Adjecent motif fitness score: 3motif: CCAGA
# adjecent_motif: CCATA
# Adjecent motif fitness score: 4motif: CCAGA
# adjecent_motif: TCAGA
# Adjecent motif fitness score: 1motif: CCAGA
# adjecent_motif: CCATA
# Adjecent motif fitness score: 4motif: CCAGA
# adjecent_motif: CCAGA
# Adjecent motif fitness score: 0motif: CCAGA
# adjecent_motif: CGAGA
# Adjecent motif fitness score: 5
# CCAGA is a discovered motif with score of 30
# motif: CCCTC
# adjecent_motif: CCCTC
# Adjecent motif fitness score: 1motif: CCCTC
# adjecent_motif: TCCTC
# Adjecent motif fitness score: 2motif: CCCTC
# adjecent_motif: CCCTC
# Adjecent motif fitness score: 1motif: CCCTC
# adjecent_motif: CCCTC
# Adjecent motif fitness score: 1motif: CCCTC
# adjecent_motif: CCCAC
# Adjecent motif fitness score: 2motif: CCCTC
# adjecent_motif: GCCTC
# Adjecent motif fitness score: 4motif: CCCTC
# adjecent_motif: CCCGC
# Adjecent motif fitness score: 6motif: CCCTC
# adjecent_motif: CCCTC
# Adjecent motif fitness score: 1motif: CCCTC
# adjecent_motif: ACCTC
# Adjecent motif fitness score: 3motif: CCCTC
# adjecent_motif: CCCTC
# Adjecent motif fitness score: 1
# CCCTC is a discovered motif with score of 29
# motif: GCCTT
# adjecent_motif: GCCAT
# Adjecent motif fitness score: 4motif: GCCTT
# adjecent_motif: GCCTA
# Adjecent motif fitness score: 2GCCTA is better than GCCTT with 1 scores.
# Going to adjecent motif.
#
# motif: GCCTA
# adjecent_motif: GCCTA
# Adjecent motif fitness score: 2motif: GCCTA
# adjecent_motif: GACTA
# Adjecent motif fitness score: 5motif: GCCTA
# adjecent_motif: GCCTA
# Adjecent motif fitness score: 2motif: GCCTA
# adjecent_motif: GCCTA
# Adjecent motif fitness score: 2motif: GCCTA
# adjecent_motif: GCCTG
# Adjecent motif fitness score: 2motif: GCCTA
# adjecent_motif: GACTA
# Adjecent motif fitness score: 5motif: GCCTA
# adjecent_motif: GCCTT
# Adjecent motif fitness score: 3motif: GCCTA
# adjecent_motif: GTCTA
# Adjecent motif fitness score: 4motif: GCCTA
# adjecent_motif: GCCTT
# Adjecent motif fitness score: 3motif: GCCTA
# adjecent_motif: GCCTA
# Adjecent motif fitness score: 2
# GCCTA is a discovered motif with score of 29
# motif: CTACG
# adjecent_motif: CTACA
# Adjecent motif fitness score: 3CTACA is better than CTACG with 2 scores.
# Going to adjecent motif.
#
# motif: CTACA
# adjecent_motif: CTACA
# Adjecent motif fitness score: 3motif: CTACA
# adjecent_motif: CTACA
# Adjecent motif fitness score: 3motif: CTACA
# adjecent_motif: CTCCA
# Adjecent motif fitness score: 0CTCCA is better than CTACA with 3 scores.
# Going to adjecent motif.
#
# motif: CTCCA
# adjecent_motif: CTCCC
# Adjecent motif fitness score: 2motif: CTCCA
# adjecent_motif: CTGCA
# Adjecent motif fitness score: 3motif: CTCCA
# adjecent_motif: TTCCA
# Adjecent motif fitness score: 2motif: CTCCA
# adjecent_motif: CTCCA
# Adjecent motif fitness score: 0motif: CTCCA
# adjecent_motif: CCCCA
# Adjecent motif fitness score: 2motif: CTCCA
# adjecent_motif: CCCCA
# Adjecent motif fitness score: 2motif: CTCCA
# adjecent_motif: CCCCA
# Adjecent motif fitness score: 2motif: CTCCA
# adjecent_motif: CTCCT
# Adjecent motif fitness score: 2motif: CTCCA
# adjecent_motif: CTCTA
# Adjecent motif fitness score: 2motif: CTCCA
# adjecent_motif: CTCCA
# Adjecent motif fitness score: 0
# CTCCA is a discovered motif with score of 30
# motif: TGCCG
# adjecent_motif: GGCCG
# Adjecent motif fitness score: 4GGCCG is better than TGCCG with 2 scores.
# Going to adjecent motif.
#
# motif: GGCCG
# adjecent_motif: GGCGG
# Adjecent motif fitness score: 5motif: GGCCG
# adjecent_motif: GGCCA
# Adjecent motif fitness score: 1GGCCA is better than GGCCG with 3 scores.
# Going to adjecent motif.
#
# motif: GGCCA
# adjecent_motif: GGCAA
# Adjecent motif fitness score: 1motif: GGCCA
# adjecent_motif: GGACA
# Adjecent motif fitness score: 1motif: GGCCA
# adjecent_motif: CGCCA
# Adjecent motif fitness score: 6motif: GGCCA
# adjecent_motif: AGCCA
# Adjecent motif fitness score: 1motif: GGCCA
# adjecent_motif: GGCCA
# Adjecent motif fitness score: 1motif: GGCCA
# adjecent_motif: GGCCA
# Adjecent motif fitness score: 1motif: GGCCA
# adjecent_motif: GGCGA
# Adjecent motif fitness score: 7motif: GGCCA
# adjecent_motif: GGCCT
# Adjecent motif fitness score: 4motif: GGCCA
# adjecent_motif: AGCCA
# Adjecent motif fitness score: 1motif: GGCCA
# adjecent_motif: GCCCA
# Adjecent motif fitness score: 3
# GGCCA is a discovered motif with score of 29
# motif: GCTGT
# adjecent_motif: GCTGT
# Adjecent motif fitness score: 2motif: GCTGT
# adjecent_motif: GCCGT
# Adjecent motif fitness score: 6motif: GCTGT
# adjecent_motif: GCCGT
# Adjecent motif fitness score: 6motif: GCTGT
# adjecent_motif: GGTGT
# Adjecent motif fitness score: 4motif: GCTGT
# adjecent_motif: GCTGT
# Adjecent motif fitness score: 2motif: GCTGT
# adjecent_motif: GTTGT
# Adjecent motif fitness score: 5motif: GCTGT
# adjecent_motif: GCTCT
# Adjecent motif fitness score: 1GCTCT is better than GCTGT with 1 scores.
# Going to adjecent motif.
#
# motif: GCTCT
# adjecent_motif: GCTCA
# Adjecent motif fitness score: 4motif: GCTCT
# adjecent_motif: GCCCT
# Adjecent motif fitness score: 1motif: GCTCT
# adjecent_motif: GCACT
# Adjecent motif fitness score: 3motif: GCTCT
# adjecent_motif: GCTCC
# Adjecent motif fitness score: 3motif: GCTCT
# adjecent_motif: GCTCT
# Adjecent motif fitness score: 1motif: GCTCT
# adjecent_motif: GCTCT
# Adjecent motif fitness score: 1motif: GCTCT
# adjecent_motif: GCACT
# Adjecent motif fitness score: 3motif: GCTCT
# adjecent_motif: ACTCT
# Adjecent motif fitness score: 2motif: GCTCT
# adjecent_motif: CCTCT
# Adjecent motif fitness score: 1motif: GCTCT
# adjecent_motif: GCACT
# Adjecent motif fitness score: 3
# GCTCT is a discovered motif with score of 29
# motif: ATCAA
# adjecent_motif: AACAA
# Adjecent motif fitness score: 2motif: ATCAA
# adjecent_motif: TTCAA
# Adjecent motif fitness score: 2motif: ATCAA
# adjecent_motif: GTCAA
# Adjecent motif fitness score: 1GTCAA is better than ATCAA with 1 scores.
# Going to adjecent motif.
#
# motif: GTCAA
# adjecent_motif: GTCAA
# Adjecent motif fitness score: 1motif: GTCAA
# adjecent_motif: GTCAG
# Adjecent motif fitness score: 2motif: GTCAA
# adjecent_motif: GACAA
# Adjecent motif fitness score: 1motif: GTCAA
# adjecent_motif: GTCTA
# Adjecent motif fitness score: 4motif: GTCAA
# adjecent_motif: CTCAA
# Adjecent motif fitness score: 3motif: GTCAA
# adjecent_motif: GTCAC
# Adjecent motif fitness score: 2motif: GTCAA
# adjecent_motif: GTCAA
# Adjecent motif fitness score: 1motif: GTCAA
# adjecent_motif: GTGAA
# Adjecent motif fitness score: 1motif: GTCAA
# adjecent_motif: GGCAA
# Adjecent motif fitness score: 1motif: GTCAA
# adjecent_motif: GTCCA
# Adjecent motif fitness score: 1
# GTCAA is a discovered motif with score of 29
# motif: GCTTC
# adjecent_motif: GCGTC
# Adjecent motif fitness score: 6motif: GCTTC
# adjecent_motif: GCTTG
# Adjecent motif fitness score: 2motif: GCTTC
# adjecent_motif: GTTTC
# Adjecent motif fitness score: 5motif: GCTTC
# adjecent_motif: GCTTC
# Adjecent motif fitness score: 2motif: GCTTC
# adjecent_motif: GTTTC
# Adjecent motif fitness score: 5motif: GCTTC
# adjecent_motif: GCTTC
# Adjecent motif fitness score: 2motif: GCTTC
# adjecent_motif: GCTCC
# Adjecent motif fitness score: 3motif: GCTTC
# adjecent_motif: GCTTC
# Adjecent motif fitness score: 2motif: GCTTC
# adjecent_motif: GCGTC
# Adjecent motif fitness score: 6motif: GCTTC
# adjecent_motif: CCTTC
# Adjecent motif fitness score: 2
# GCTTC is a discovered motif with score of 29
# 10 motif(s) with length of 5 motifs were discovered.
